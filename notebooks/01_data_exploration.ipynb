# %%
import pandas as pd 

students = {
    "Name" : ["Ash" , "Rahul"],
    "Age" : [19 , 20]
}

df = pd.DataFrame(students)

# df

df.loc[0]
# Out:
# Name    Ash
# Age      19
# Name: 0, dtype: object
